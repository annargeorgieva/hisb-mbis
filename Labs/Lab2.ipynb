# %% [markdown]
# Импортиране на библиотеките Numpy и Pandaр които служат за прочитане и обработка на данни от бази данни.

# %%
import numpy as np
import pandas as ps

# %% [markdown]
# Прочитане на данни от файл и извеждането на първите 7.

# %%
hd = ps.read_csv('sample_data/Heart_disease_details.csv')

hd.head(7)
# Out:
#                Name  Gender  Age  Chest pain  Shortness of breath  Fatigue  \
# 0          Jane Doe  Female   55           1                    1        1
# 1      Mark Johnson    Male   57           1                    1        1
# 2       Emily Davis  Female   60           1                    1        1
# 3  William Thompson    Male   62           1                    1        1
# 4    Ashley Johnson  Female   58           1                    1        1
# 5       Brian Brown    Male   55           1                    1        1
# 6       Emily Davis  Female   60           1                    1        1
#
#    Systolic  Diastolic  Heart rate (bpm)  Lung sounds  ...  \
# 0       140         90               100            1  ...
# 1       150         80               110            1  ...
# 2       130         85                95            1  ...
# 3       145         90               100            1  ...
# 4       135         80               105            1  ...
# ...

# %% [markdown]
# Различни обработвания на данните.

# %%
hd.shape
# Out:
# (334, 49)

# %%
hd.columns
# Out:
# Index(['Name', 'Gender', 'Age', 'Chest pain', 'Shortness of breath', 'Fatigue',
#        'Systolic', 'Diastolic', 'Heart rate (bpm)', 'Lung sounds',
#        'Cholesterol level (mg/dL)', 'LDL level (mg/dL)', 'HDL level (mg/dL)',
#        'Diabetes', 'Atrial fibrillation', 'Mitral valve prolapse',
#        'Rheumatic fever', 'Mitral stenosis', 'Aortic stenosis',
#        'Tricuspid stenosis', 'Pulmonary stenosis', 'Dilated cardiomyopathy',
#        'Hypertrophic cardiomyopathy', 'Restrictive cardiomyopathy',
#        'Arrhythmogenic right ventricular cardiomyopathy',
#        'Takotsubo cardiomyopathy', 'Drug use', 'Fever', 'Chills', 'Joint pain',
#        'Alcoholism', 'Hypertension', 'Fainting', 'Dizziness', 'Smoking',
#        'High cholesterol', 'Echocardiogram', 'Blood culture', 'EKG',
#        'Cardiac CT', 'Obesity', 'Murmur', 'Chest x-ray', 'Previous illnesses',
#        'Pulmonary function tests', 'Spirometry', 'Diagnosis', 'Medications',
#        'Treatment'],
# ...

# %%
hd.describe()
# Out:
#               Age  Chest pain  Shortness of breath     Fatigue    Systolic  \
# count  334.000000  334.000000           334.000000  334.000000  334.000000
# mean    50.149701    0.880240             0.826347    0.979042  133.098802
# std     15.151935    0.325168             0.379379    0.143459   10.040121
# min     23.000000    0.000000             0.000000    0.000000  110.000000
# 25%     40.000000    1.000000             1.000000    1.000000  130.000000
# 50%     50.000000    1.000000             1.000000    1.000000  130.000000
# 75%     61.500000    1.000000             1.000000    1.000000  140.000000
# max    100.000000    1.000000             1.000000    1.000000  160.000000
#
#         Diastolic  Heart rate (bpm)  Lung sounds  Cholesterol level (mg/dL)  \
# count  334.000000        334.000000   334.000000                 334.000000
# mean    83.203593        101.152695     0.859281                 213.637725
# ...

# %%
hd.describe(include='object')
# Out:
#                Name Gender Echocardiogram Blood culture   EKG Cardiac CT  \
# count           334    334            334           334   334        334
# unique          171      2             18            22    60         81
# top     Emily Davis   Male           None          None  None       None
# freq             21    168            218           276    57        117
#
#        Chest x-ray Previous illnesses Pulmonary function tests Spirometry  \
# count          334                334                      334        334
# unique          13                  6                        5          2
# top           None               None                     None       None
# freq           277                317                      287        324
#
#                                                 Diagnosis  \
# count                                                 334
# unique                                                 31
# ...

# %%
hd.Gender.value_counts()
# Out:
# Male      168
# Female    166
# Name: Gender, dtype: int64

# %% [markdown]
# Нивото на холестерола е пример за продължителна променлива. Чрез него може да се види зависимостта между повишаването на нивото му и покачването на шанса от сърдечно-съдови заболявания.
#
# Полът е категорийна атрибутивна променлива с две стойности. Може да се наблюдава дали сърдечно-съдовите забовялания и полът имат зависимост едни от други.
