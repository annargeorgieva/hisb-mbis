# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('sports_injury_data.csv')

# %%
X = data[['age', 'previous_injuries', 'physical_activity', 'training_load', 'previous_matches']]
y = data['injury']

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Точност на модела: {accuracy}")
# Out:
# Точност на модела: 0.0

# %%
importances = model.feature_importances_
feature_names = X.columns

# %%
plt.bar(feature_names, importances)
plt.xlabel('Характеристики')
plt.ylabel('Важност')
plt.title('Важност на характеристиките в предвиждането на контузии')
plt.xticks(rotation=90)
plt.show()
